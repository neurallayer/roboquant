// %%
%use roboquant(0.9-SNAPSHOT)
Output.lab()
val feed = AvroFeed.usTest()
// Out:
//             <div id="kotlin_out_0"/>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["echarts"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["echarts"] = resQueue;
//                 window["call_echarts"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/npm/echarts@5/dist/echarts.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_echarts"] = function(f) {f();};
//                         window.kotlinQueues["echarts"].forEach(function(f) {f();});
//                         window.kotlinQueues["echarts"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_echarts"] = function(f) {};
//                         window.kotlinQueues["echarts"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource echarts';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
val strategy = EMACrossover(50, 200)
val roboquant =  Roboquant(strategy, AccountSummary())
val timeframe = Timeframe.fromYears(2019, 2020)
roboquant.run(feed, timeframe)
// Out:
// 2019-01-01 - 2020-12-31 | 100% |████████████████████████████████████████| run-0 | episode=1 | phase=MAIN

// %%
val account = roboquant.broker.account
AssetAllocationChart(account, includeCash = false, includeAssetClass=false)
// Out:
//         <div style="width:100%;height:500px;" class="rqcharts"></div>
//
//         <script type="text/javascript">
//             (function () {
//                 let elem = document.currentScript.previousElementSibling;
//                 let fn = function(a) {
//                     var theme = document.body.dataset.jpThemeLight == 'false' ? 'dark' : 'light';
//                     var myChart = echarts.init(elem, theme);
//                     var option = {
//                 title: { text: 'Asset allocation' },
//                 tooltip : {},
//                 toolbox: { feature: {
//                     dataZoom: { yAxisIndex: 'none'},
//                     dataView: {readOnly: true},
//                     restore: {},
//                     saveAsImage: {}
//                 }},
//                 grid: { left: '3%', right: '3%', containLabel: true },
//                 series : [ {
//     type: 'pie',
//     radius: '80%',
//     emphasis: {
//         itemStyle: {
//             shadowBlur: 10,
//             shadowOffsetX: 0,
//             shadowColor: 'rgba(0, 0, 0, 0.5)'
//         }
//     },
//     data : [{"name":"AMZN","value":35826.23,"type":"STOCK"},{"name":"IBM","value":20014.95,"type":"STOCK"},{"name":"JNJ","value":22403.95,"type":"STOCK"},{"name":"JPM","value":22311.00,"type":"STOCK"},{"name":"TSLA","value":223697.39,"type":"STOCK"}]
// }]
//             }
//        ;
//                     option && (option.backgroundColor = 'rgba(0,0,0,0)');
//                     option && myChart.setOption(option);
//                     elem.ondblclick = function () { myChart.resize() };
//                     console.log('rendered new chart');
//                 }
//                 call_echarts(fn)
//             })()
//         </script>

// %%
AssetAllocationChart(account, includeCash = true, includeAssetClass=true)
// Out:
//         <div style="width:100%;height:500px;" class="rqcharts"></div>
//
//         <script type="text/javascript">
//             (function () {
//                 let elem = document.currentScript.previousElementSibling;
//                 let fn = function(a) {
//                     var theme = document.body.dataset.jpThemeLight == 'false' ? 'dark' : 'light';
//                     var myChart = echarts.init(elem, theme);
//                     var option = {
//                 title: { text: 'Asset allocation' },
//                 tooltip : {},
//                 toolbox: {
//     feature: {
//       dataZoom: { yAxisIndex: 'none' },
//       dataView: {readOnly: true},
//       saveAsImage: {},
//       restore: {},
//       myFeature: {
//         show: true,
//         title: 'Pie/Map',
//         icon: 'path://M432.45,595.444c0,2.177-4.661,6.82-11.305,6.82c-6.475,0-11.306-4.567-11.306-6.82s4.852-6.812,11.306-6.812C427.841,588.632,432.452,593.191,432.45,595.444L432.45,595.444z M421.155,589.876c-3.009,0-5.448,2.495-5.448,5.572s2.439,5.572,5.448,5.572c3.01,0,5.449-2.495,5.449-5.572C426.604,592.371,424.165,589.876,421.155,589.876L421.155,589.876z M421.146,591.891c-1.916,0-3.47,1.589-3.47,3.549c0,1.959,1.554,3.548,3.47,3.548s3.469-1.589,3.469-3.548C424.614,593.479,423.062,591.891,421.146,591.891L421.146,591.891zM421.146,591.891',
//         onclick: function () {
//             let currentType = myChart.getOption().series[0].type;
//             option.series[0].type = currentType === 'sunburst' ? 'treemap' : 'sunburst';
//             myChart.setOption(option);
//         }
//       }
//     }
// },
//                 series : [ {
//     type: 'sunburst',
//     radius: '80%',
//     data : [{"name":"CASH","children":[{"name":"USD","value":899153.00,"type":"CASH"}]},{"name":"STOCK","children":[{"name":"AMZN","value":35826.23,"type":"STOCK"},{"name":"IBM","value":20014.95,"type":"STOCK"},{"name":"JNJ","value":22403.95,"type":"STOCK"},{"name":"JPM","value":22311.00,"type":"STOCK"},{"name":"TSLA","value":223697.39,"type":"STOCK"}]}]
// }]
//             };
//                     option && (option.backgroundColor = 'rgba(0,0,0,0)');
//                     option && myChart.setOption(option);
//                     elem.ondblclick = function () { myChart.resize() };
//                     console.log('rendered new chart');
//                 }
//                 call_echarts(fn)
//             })()
//         </script>

// %%
val trades = account.trades.filter { it.pnl.value < -100 }
TradeChart(account.trades)
// Out:
//  <div style="width:100%;height:500px;" class="rqcharts"></div>
//
//  <script type="text/javascript">
//      (function () {
//          let elem = document.currentScript.previousElementSibling;
//          let fn = function(a) {
//              var theme = document.body.dataset.jpThemeLight == 'false' ? 'dark' : 'light';
//              var myChart = echarts.init(elem, theme);
//              var option = {
//          xAxis: {
//              type: 'time',
//              scale: true
//          },
//          title: {
//              text: 'Trade Chart pnl'
//          },
//          yAxis: {
//              type: 'value',
//              scale: true
//          },
//          visualMap: {
//             min: -911.43,
//             max: 911.43,
//             calculable: true,
//             orient: 'horizontal',
//             left: 'center',
//             dimension: 1,
//             top: 'top',
//             inRange : { color: ['#FF0000', '#00FF00'] }
//          },
//          tooltip: {
//               formatter: function (params) {
//                  return params.value[2];
//               }
//          },
//          dataZoom: [{ type: 'inside'}, {}],
//          toolbox: { feature: {
//              dataZoom: { yAxisIndex: 'none'},
//              dataView: {readOnly: true},
//              restore: {},
//              saveAsImage: {}
//          }},
//          grid: { left: '3%', right: '3%', containLabel: true },
//          series : [
//      {
//          type: 'scatter',
//          symbolSize: 10,
//          data : [[1572552000000,0.00,"asset: STOCK TSLA \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2019-10-31T20:00:00Z\u003cbr\u003e\nqty: 317.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: 0.00\u003cbr\u003e\ncost: 19985.89\u003cbr\u003e\norder: 0"],[1574456400000,0.00,"asset: STOCK JNJ \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2019-11-22T21:00:00Z\u003cbr\u003e\nqty: 154.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: 0.00\u003cbr\u003e\ncost: 20203.42\u003cbr\u003e\norder: 1"],[1574888400000,0.00,"asset: STOCK AMZN \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2019-11-27T21:00:00Z\u003cbr\u003e\nqty: 11.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: 0.00\u003cbr\u003e\ncost: 20023.61\u003cbr\u003e\norder: 2"],[1576011600000,-911.43,"asset: STOCK AMZN \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2019-12-10T21:00:00Z\u003cbr\u003e\nqty: -11.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: -911.43\u003cbr\u003e\ncost: -19112.18\u003cbr\u003e\norder: 3"],[1577221200000,0.00,"asset: STOCK AMZN \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2019-12-24T21:00:00Z\u003cbr\u003e\nqty: 11.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: 0.00\u003cbr\u003e\ncost: 19700.99\u003cbr\u003e\norder: 4"],[1585857600000,-498.83,"asset: STOCK JNJ \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2020-04-02T20:00:00Z\u003cbr\u003e\nqty: -154.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: -498.83\u003cbr\u003e\ncost: -19704.60\u003cbr\u003e\norder: 5"],[1586462400000,0.00,"asset: STOCK JNJ \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2020-04-09T20:00:00Z\u003cbr\u003e\nqty: 145.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: 0.00\u003cbr\u003e\ncost: 19717.95\u003cbr\u003e\norder: 6"],[1605301200000,0.00,"asset: STOCK JPM \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2020-11-13T21:00:00Z\u003cbr\u003e\nqty: 180.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: 0.00\u003cbr\u003e\ncost: 20050.43\u003cbr\u003e\norder: 7"],[1608238800000,0.00,"asset: STOCK IBM \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2020-12-17T21:00:00Z\u003cbr\u003e\nqty: 167.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: 0.00\u003cbr\u003e\ncost: 19981.47\u003cbr\u003e\norder: 8"]]
//      }
//  ]
//      }
// ;
//              option && (option.backgroundColor = 'rgba(0,0,0,0)');
//              option && myChart.setOption(option);
//              elem.ondblclick = function () { myChart.resize() };
//              console.log('rendered new chart');
//          }
//          call_echarts(fn)
//      })()
//  </script>

// %%
val chart = TradeChartByAsset(trades)
chart.height = 1000
chart
// Out:
//  <div style="width:100%;height:1000px;" class="rqcharts"></div>
//
//  <script type="text/javascript">
//      (function () {
//          let elem = document.currentScript.previousElementSibling;
//          let fn = function(a) {
//              var theme = document.body.dataset.jpThemeLight == 'false' ? 'dark' : 'light';
//              var myChart = echarts.init(elem, theme);
//              var option = {
//          xAxis: {
//              type: 'time',
//              scale: true
//          },
//          title: {
//              text: 'Trade Chart pnl'
//          },
//          yAxis: {
//              type: 'category',
//              data: ["AMZN","JNJ"],
//              splitArea: {show: true}
//          },
//          tooltip: {
//               formatter: function (params) {
//                  return params.value[3];
//               }
//          },
//          toolbox: {
//              feature: {
//                  dataZoom: { },
//                  dataView: {readOnly: true},
//                  restore: {},
//                  saveAsImage: {}
//              }
//          },
//          dataZoom: [{ type: 'inside'}, {}],
//          grid: { left: '3%', right: '3%', containLabel: true },
//          series : [
//      {
//          type: 'scatter',
//          symbolSize: 10,
//          data : [[1576011600000,0,-911.43,"asset: STOCK AMZN  \u003cbr\u003e currency: USD \u003cbr\u003e time: 2019-12-10T21:00:00Z \u003cbr\u003e qty: -11.0 \u003cbr\u003e fee: 0.00 \u003cbr\u003e pnl: -911.43 \u003cbr\u003e cost: -19112.18 \u003cbr\u003e order: 3"],[1585857600000,1,-498.83,"asset: STOCK JNJ  \u003cbr\u003e currency: USD \u003cbr\u003e time: 2020-04-02T20:00:00Z \u003cbr\u003e qty: -154.0 \u003cbr\u003e fee: 0.00 \u003cbr\u003e pnl: -498.83 \u003cbr\u003e cost: -19704.60 \u003cbr\u003e order: 5"]]
//      }
//  ]
//      }
// ;
//              option && (option.backgroundColor = 'rgba(0,0,0,0)');
//              option && myChart.setOption(option);
//              elem.ondblclick = function () { myChart.resize() };
//              console.log('rendered new chart');
//          }
//          call_echarts(fn)
//      })()
//  </script>

// %%
TradeChart(trades, aspect = "cost")
// Out:
//  <div style="width:100%;height:500px;" class="rqcharts"></div>
//
//  <script type="text/javascript">
//      (function () {
//          let elem = document.currentScript.previousElementSibling;
//          let fn = function(a) {
//              var theme = document.body.dataset.jpThemeLight == 'false' ? 'dark' : 'light';
//              var myChart = echarts.init(elem, theme);
//              var option = {
//          xAxis: {
//              type: 'time',
//              scale: true
//          },
//          title: {
//              text: 'Trade Chart cost'
//          },
//          yAxis: {
//              type: 'value',
//              scale: true
//          },
//          visualMap: {
//             min: -19704.60,
//             max: 19704.60,
//             calculable: true,
//             orient: 'horizontal',
//             left: 'center',
//             dimension: 1,
//             top: 'top',
//             inRange : { color: ['#FF0000', '#00FF00'] }
//          },
//          tooltip: {
//               formatter: function (params) {
//                  return params.value[2];
//               }
//          },
//          dataZoom: [{ type: 'inside'}, {}],
//          toolbox: { feature: {
//              dataZoom: { yAxisIndex: 'none'},
//              dataView: {readOnly: true},
//              restore: {},
//              saveAsImage: {}
//          }},
//          grid: { left: '3%', right: '3%', containLabel: true },
//          series : [
//      {
//          type: 'scatter',
//          symbolSize: 10,
//          data : [[1576011600000,-19112.18,"asset: STOCK AMZN \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2019-12-10T21:00:00Z\u003cbr\u003e\nqty: -11.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: -911.43\u003cbr\u003e\ncost: -19112.18\u003cbr\u003e\norder: 3"],[1585857600000,-19704.60,"asset: STOCK JNJ \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2020-04-02T20:00:00Z\u003cbr\u003e\nqty: -154.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: -498.83\u003cbr\u003e\ncost: -19704.60\u003cbr\u003e\norder: 5"]]
//      }
//  ]
//      }
// ;
//              option && (option.backgroundColor = 'rgba(0,0,0,0)');
//              option && myChart.setOption(option);
//              elem.ondblclick = function () { myChart.resize() };
//              console.log('rendered new chart');
//          }
//          call_echarts(fn)
//      })()
//  </script>

// %%
val asset = account.assets.first()
val timeframe = Timeframe.parse("2019-01-01", "2019-01-15")
PriceBarChart(feed, asset, account.trades, timeframe)
// Out:
//         <div style="width:100%;height:700px;" class="rqcharts"></div>
//
//         <script type="text/javascript">
//             (function () {
//                 let elem = document.currentScript.previousElementSibling;
//                 let fn = function(a) {
//                     var theme = document.body.dataset.jpThemeLight == 'false' ? 'dark' : 'light';
//                     var myChart = echarts.init(elem, theme);
//                     var option = {
// dataset: {
//     source: [[1546462800000,61.22,63.026,59.76,62.024,5.829324E7,1],[1546549200000,61.4,61.88,59.476,60.072,3.482592E7,-1],[1546635600000,61.2,63.6,60.546,63.538,3.697058E7,1],[1546894800000,64.344,67.348,63.55,66.992,3.7756125E7,1],[1546981200000,68.392,68.802,65.404,67.07,3.504258E7,-1],[1547067600000,67.1,68.701,66.294,67.706,2.7164725E7,1],[1547154000000,66.88,69.078,66.358,68.994,3.028177E7,1],[1547240400000,68.418,69.682,67.754,69.452,2.519526E7,1],[1547499600000,68.476,68.5,66.8,66.88,2.623642E7,-1]]
// },
// title: {
//     text: 'TSLA 2019-01-02 - 2019-01-14'
// },
// tooltip: {
//     trigger: 'axis',
//     axisPointer: {
//         type: 'line'
//     }
// },
// toolbox: { feature: {
//     dataZoom: { yAxisIndex: 'none'},
//     dataView: {readOnly: true}, magicType: {type: ['line', 'bar']},
//     restore: {},
//     saveAsImage: {}
// }},
// grid: [
//     {
//         left: 80,
//         right: '3%',
//         bottom: 200
//     },
//     {
//         left: 80,
//         right: '3%',
//         height: 80,
//         bottom: 80
//     }
// ],
// xAxis: [
//     {
//         type: 'time',
//         scale: true,
//         boundaryGap: true,
//         axisLine: {onZero: false},
//         splitLine: {show: false},
//         splitNumber: 20,
//         min: 'dataMin',
//         max: 'dataMax'
//     },
//     {
//         type: 'time',
//         gridIndex: 1,
//         scale: true,
//         boundaryGap: true,
//         axisLine: {onZero: false},
//         axisTick: {show: false},
//         splitLine: {show: false},
//         axisLabel: {show: false},
//         splitNumber: 20,
//         min: 'dataMin',
//         max: 'dataMax'
//     }
// ],
// yAxis: [
//     {
//         scale: true,
//         splitArea: {
//             show: true
//         }
//     },
//     {
//         scale: true,
//         gridIndex: 1,
//         splitNumber: 2,
//         axisLabel: {show: false},
//         axisLine: {show: false},
//         axisTick: {show: false},
//         splitLine: {show: false}
//     }
// ],
// dataZoom: [
//     {
//         type: 'inside',
//         xAxisIndex: [0, 1],
//         start: 0,
//         end: 100
//     },
//     {
//         show: true,
//         xAxisIndex: [0, 1],
//         type: 'slider',
//         bottom: 10,
//         start: 0,
//         end: 100
//     }
// ],
// visualMap: {
//     show: false,
//     seriesIndex: 1,
//     dimension: 6,
//     pieces: [{
//         value: 1,
//         color: 'green'
//     }, {
//         value: -1,
//         color: 'red'
//     }]
// },
// series: [
//     {
//         type: 'candlestick',
//         name: 'TSLA',
//         itemStyle: {
//             color: 'green',
//             color0: 'red',
//             borderColor: 'green',
//             borderColor0: 'red'
//         },
//          markPoint: {
//                 data: [],
//                 itemStyle : {
//                     color: "yellow"
//                 }
//         },
//         encode: {
//             x: 0,
//             y: [1, 4, 3, 2]
//         },
//
//     },
//     {
//         name: 'Volume',
//         type: 'bar',
//         xAxisIndex: 1,
//         yAxisIndex: 1,
//         itemStyle: {
//             color: '#7fbe9e'
//         },
//         large: true,
//         encode: {
//             x: 0,
//             y: 5
//         }
//     }
// ]
// };;
//                     option && (option.backgroundColor = 'rgba(0,0,0,0)');
//                     option && myChart.setOption(option);
//                     elem.ondblclick = function () { myChart.resize() };
//                     console.log('rendered new chart');
//                 }
//                 call_echarts(fn)
//             })()
//         </script>

// %%
val orders = account.closedOrders.filter { it.asset.symbol.startsWith("A") }
OrderChart(orders)
// Out:
//         <div style="width:100%;height:500px;" class="rqcharts"></div>
//
//         <script type="text/javascript">
//             (function () {
//                 let elem = document.currentScript.previousElementSibling;
//                 let fn = function(a) {
//                     var theme = document.body.dataset.jpThemeLight == 'false' ? 'dark' : 'light';
//                     var myChart = echarts.init(elem, theme);
//                     var option = {
//              xAxis: {
//                  type: 'time',
//                  scale: true
//              },
//              title: {
//                  text: 'Order Chart quantity'
//              },
//              yAxis: {
//                  type: 'value',
//                  scale: true
//              },
//              visualMap: {
//     min: -11.0,
//     max: 11.0,
//     calculable: true,
//     orient: 'horizontal',
//     left: 'center',
//     dimension: 1,
//     top: 'top',
//     inRange : { color: ['#FF0000', '#00FF00'] }
// },
//              tooltip: {
//                   formatter: function (params) {
//                      return params.value[2];
//                   }
//              },
//              dataZoom: [{ type: 'inside'}, {}],
//              toolbox: { feature: {
//                  dataZoom: { yAxisIndex: 'none'},
//                  dataView: {readOnly: true},
//                  restore: {},
//                  saveAsImage: {}
//              }},
//              grid: { left: '3%', right: '3%', containLabel: true },
//              series : [
//          {
//              type: 'scatter',
//              symbolSize: 10,
//              data : [[1574888400000,11.0,"asset: STOCK AMZN  \u003cbr\u003e currency: USD \u003cbr\u003e placed: 2019-11-27T21:00:00Z \u003cbr\u003e qty: 11.0 \u003cbr\u003e id: 2 \u003cbr\u003e type: MarketOrder \u003cbr\u003e tif: GTC"],[1576011600000,-11.0,"asset: STOCK AMZN  \u003cbr\u003e currency: USD \u003cbr\u003e placed: 2019-12-10T21:00:00Z \u003cbr\u003e qty: -11.0 \u003cbr\u003e id: 3 \u003cbr\u003e type: MarketOrder \u003cbr\u003e tif: GTC"],[1577221200000,11.0,"asset: STOCK AMZN  \u003cbr\u003e currency: USD \u003cbr\u003e placed: 2019-12-24T21:00:00Z \u003cbr\u003e qty: 11.0 \u003cbr\u003e id: 4 \u003cbr\u003e type: MarketOrder \u003cbr\u003e tif: GTC"]]
//          }
//      ]
//          };
//                     option && (option.backgroundColor = 'rgba(0,0,0,0)');
//                     option && myChart.setOption(option);
//                     elem.ondblclick = function () { myChart.resize() };
//                     console.log('rendered new chart');
//                 }
//                 call_echarts(fn)
//             })()
//         </script>
