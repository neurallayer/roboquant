// %%
%use roboquant(0.9-SNAPSHOT)
Output.lab()
val feed = AvroFeed.usTest()
// Out:
//             <div id="kotlin_out_0"/>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["echarts"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["echarts"] = resQueue;
//                 window["call_echarts"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/npm/echarts@5/dist/echarts.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_echarts"] = function(f) {f();};
//                         window.kotlinQueues["echarts"].forEach(function(f) {f();});
//                         window.kotlinQueues["echarts"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_echarts"] = function(f) {};
//                         window.kotlinQueues["echarts"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource echarts';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
val strategy = EMACrossover(50, 200)
val roboquant =  Roboquant(strategy, AccountSummary())
val timeframe = Timeframe.fromYears(2015, 2016)
roboquant.run(feed, timeframe)
// Out:
// 2015-01-01 - 2016-12-31 | 100% |████████████████████████████████████████| run-0 | episode=1 | phase=MAIN

// %%
val account = roboquant.broker.account
AssetAllocationChart(account, includeCash = false, includeAssetClass=false)
// Out:
//         <div style="width:100%;height:500px;" class="rqcharts"></div>
//
//         <script type="text/javascript">
//             (function () {
//                 let elem = document.currentScript.previousElementSibling;
//                 let fn = function(a) {
//                     var theme = document.body.dataset.jpThemeLight == 'false' ? 'dark' : 'light';
//                     var myChart = echarts.init(elem, theme);
//                     var option = {
//                 title: { text: 'Asset allocation' },
//                 tooltip : {},
//                 toolbox: { feature: {
//                     dataZoom: { yAxisIndex: 'none'},
//                     dataView: {readOnly: true},
//                     restore: {},
//                     saveAsImage: {}
//                 }},
//                 grid: { left: '3%', right: '3%', containLabel: true },
//                 series : [ {
//     type: 'pie',
//     radius: '80%',
//     emphasis: {
//         itemStyle: {
//             shadowBlur: 10,
//             shadowOffsetX: 0,
//             shadowColor: 'rgba(0, 0, 0, 0.5)'
//         }
//     },
//     data : [{"name":"AAPL","value":21367.92,"type":"STOCK"},{"name":"IBM","value":22434.90,"type":"STOCK"},{"name":"JNJ","value":23580.48,"type":"STOCK"},{"name":"JPM","value":27328.82,"type":"STOCK"}]
// }]
//             }
//        ;
//                     option && (option.backgroundColor = 'rgba(0,0,0,0)');
//                     option && myChart.setOption(option);
//                     elem.ondblclick = function () { myChart.resize() };
//                     console.log('rendered new chart');
//                 }
//                 call_echarts(fn)
//             })()
//         </script>

// %%
AssetAllocationChart(account, includeCash = true, includeAssetClass=true)
// Out:
//         <div style="width:100%;height:500px;" class="rqcharts"></div>
//
//         <script type="text/javascript">
//             (function () {
//                 let elem = document.currentScript.previousElementSibling;
//                 let fn = function(a) {
//                     var theme = document.body.dataset.jpThemeLight == 'false' ? 'dark' : 'light';
//                     var myChart = echarts.init(elem, theme);
//                     var option = {
//                 title: { text: 'Asset allocation' },
//                 tooltip : {},
//                 toolbox: {
//     feature: {
//       dataZoom: { yAxisIndex: 'none' },
//       dataView: {readOnly: true},
//       saveAsImage: {},
//       restore: {},
//       myFeature: {
//         show: true,
//         title: 'Pie/Map',
//         icon: 'path://M432.45,595.444c0,2.177-4.661,6.82-11.305,6.82c-6.475,0-11.306-4.567-11.306-6.82s4.852-6.812,11.306-6.812C427.841,588.632,432.452,593.191,432.45,595.444L432.45,595.444z M421.155,589.876c-3.009,0-5.448,2.495-5.448,5.572s2.439,5.572,5.448,5.572c3.01,0,5.449-2.495,5.449-5.572C426.604,592.371,424.165,589.876,421.155,589.876L421.155,589.876z M421.146,591.891c-1.916,0-3.47,1.589-3.47,3.549c0,1.959,1.554,3.548,3.47,3.548s3.469-1.589,3.469-3.548C424.614,593.479,423.062,591.891,421.146,591.891L421.146,591.891zM421.146,591.891',
//         onclick: function () {
//             let currentType = myChart.getOption().series[0].type;
//             option.series[0].type = currentType === 'sunburst' ? 'treemap' : 'sunburst';
//             myChart.setOption(option);
//         }
//       }
//     }
// },
//                 series : [ {
//     type: 'sunburst',
//     radius: '80%',
//     data : [{"name":"CASH","children":[{"name":"USD","value":910404.80,"type":"CASH"}]},{"name":"STOCK","children":[{"name":"AAPL","value":21367.92,"type":"STOCK"},{"name":"IBM","value":22434.90,"type":"STOCK"},{"name":"JNJ","value":23580.48,"type":"STOCK"},{"name":"JPM","value":27328.82,"type":"STOCK"}]}]
// }]
//             };
//                     option && (option.backgroundColor = 'rgba(0,0,0,0)');
//                     option && myChart.setOption(option);
//                     elem.ondblclick = function () { myChart.resize() };
//                     console.log('rendered new chart');
//                 }
//                 call_echarts(fn)
//             })()
//         </script>

// %%
val trades = account.trades.filter { it.pnl.value < -1000 }
TradeChart(account.trades)
// Out:
//  <div style="width:100%;height:500px;" class="rqcharts"></div>
//
//  <script type="text/javascript">
//      (function () {
//          let elem = document.currentScript.previousElementSibling;
//          let fn = function(a) {
//              var theme = document.body.dataset.jpThemeLight == 'false' ? 'dark' : 'light';
//              var myChart = echarts.init(elem, theme);
//              var option = {
//          xAxis: {
//              type: 'time',
//              scale: true
//          },
//          title: {
//              text: 'Trade Chart pnl'
//          },
//          yAxis: {
//              type: 'value',
//              scale: true
//          },
//          visualMap: {
//             min: -4528.28,
//             max: 4528.28,
//             calculable: true,
//             orient: 'horizontal',
//             left: 'center',
//             dimension: 1,
//             top: 'top',
//             inRange : { color: ['#FF0000', '#00FF00'] }
//          },
//          tooltip: {
//               formatter: function (params) {
//                  return params.value[2];
//               }
//          },
//          dataZoom: [{ type: 'inside'}, {}],
//          toolbox: { feature: {
//              dataZoom: { yAxisIndex: 'none'},
//              dataView: {readOnly: true},
//              restore: {},
//              saveAsImage: {}
//          }},
//          grid: { left: '3%', right: '3%', containLabel: true },
//          series : [
//      {
//          type: 'scatter',
//          symbolSize: 10,
//          data : [[1446670800000,0.00,"asset: STOCK JPM \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2015-11-04T21:00:00Z\u003cbr\u003e\nqty: 358.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: 0.00\u003cbr\u003e\ncost: 20047.62\u003cbr\u003e\norder: 0"],[1447794000000,0.00,"asset: STOCK JNJ \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2015-11-17T21:00:00Z\u003cbr\u003e\nqty: 232.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: 0.00\u003cbr\u003e\ncost: 20043.25\u003cbr\u003e\norder: 1"],[1453237200000,-2433.40,"asset: STOCK JPM \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2016-01-19T21:00:00Z\u003cbr\u003e\nqty: -358.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: -2433.40\u003cbr\u003e\ncost: -17614.23\u003cbr\u003e\norder: 2"],[1460664000000,0.00,"asset: STOCK TSLA \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2016-04-14T20:00:00Z\u003cbr\u003e\nqty: 392.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: 0.00\u003cbr\u003e\ncost: 19855.04\u003cbr\u003e\norder: 3"],[1460664000000,0.00,"asset: STOCK IBM \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2016-04-14T20:00:00Z\u003cbr\u003e\nqty: 170.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: 0.00\u003cbr\u003e\ncost: 19945.63\u003cbr\u003e\norder: 4"],[1463688000000,0.00,"asset: STOCK JPM \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2016-05-19T20:00:00Z\u003cbr\u003e\nqty: 363.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: 0.00\u003cbr\u003e\ncost: 19840.35\u003cbr\u003e\norder: 5"],[1466712000000,-4528.28,"asset: STOCK TSLA \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2016-06-23T20:00:00Z\u003cbr\u003e\nqty: -392.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: -4528.28\u003cbr\u003e\ncost: -15326.75\u003cbr\u003e\norder: 6"],[1470081600000,0.00,"asset: STOCK TSLA \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2016-08-01T20:00:00Z\u003cbr\u003e\nqty: 425.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: 0.00\u003cbr\u003e\ncost: 20037.52\u003cbr\u003e\norder: 7"],[1472068800000,0.00,"asset: STOCK AAPL \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2016-08-24T20:00:00Z\u003cbr\u003e\nqty: 784.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: 0.00\u003cbr\u003e\ncost: 19947.64\u003cbr\u003e\norder: 8"],[1472846400000,-2856.67,"asset: STOCK TSLA \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2016-09-02T20:00:00Z\u003cbr\u003e\nqty: -425.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: -2856.67\u003cbr\u003e\ncost: -17180.85\u003cbr\u003e\norder: 9"]]
//      }
//  ]
//      }
// ;
//              option && (option.backgroundColor = 'rgba(0,0,0,0)');
//              option && myChart.setOption(option);
//              elem.ondblclick = function () { myChart.resize() };
//              console.log('rendered new chart');
//          }
//          call_echarts(fn)
//      })()
//  </script>

// %%
val chart = TradeChartByAsset(trades)
chart.height = 1000
chart
// Out:
//  <div style="width:100%;height:1000px;" class="rqcharts"></div>
//
//  <script type="text/javascript">
//      (function () {
//          let elem = document.currentScript.previousElementSibling;
//          let fn = function(a) {
//              var theme = document.body.dataset.jpThemeLight == 'false' ? 'dark' : 'light';
//              var myChart = echarts.init(elem, theme);
//              var option = {
//          xAxis: {
//              type: 'time',
//              scale: true
//          },
//          title: {
//              text: 'Trade Chart pnl'
//          },
//          yAxis: {
//              type: 'category',
//              data: ["JPM","TSLA"],
//              splitArea: {show: true}
//          },
//          tooltip: {
//               formatter: function (params) {
//                  return params.value[3];
//               }
//          },
//          toolbox: {
//              feature: {
//                  dataZoom: { },
//                  dataView: {readOnly: true},
//                  restore: {},
//                  saveAsImage: {}
//              }
//          },
//          dataZoom: [{ type: 'inside'}, {}],
//          grid: { left: '3%', right: '3%', containLabel: true },
//          series : [
//      {
//          type: 'scatter',
//          symbolSize: 10,
//          data : [[1453237200000,0,-2433.40,"asset: STOCK JPM  \u003cbr\u003e currency: USD \u003cbr\u003e time: 2016-01-19T21:00:00Z \u003cbr\u003e qty: -358.0 \u003cbr\u003e fee: 0.00 \u003cbr\u003e pnl: -2433.40 \u003cbr\u003e cost: -17614.23 \u003cbr\u003e order: 2"],[1466712000000,1,-4528.28,"asset: STOCK TSLA  \u003cbr\u003e currency: USD \u003cbr\u003e time: 2016-06-23T20:00:00Z \u003cbr\u003e qty: -392.0 \u003cbr\u003e fee: 0.00 \u003cbr\u003e pnl: -4528.28 \u003cbr\u003e cost: -15326.75 \u003cbr\u003e order: 6"],[1472846400000,1,-2856.67,"asset: STOCK TSLA  \u003cbr\u003e currency: USD \u003cbr\u003e time: 2016-09-02T20:00:00Z \u003cbr\u003e qty: -425.0 \u003cbr\u003e fee: 0.00 \u003cbr\u003e pnl: -2856.67 \u003cbr\u003e cost: -17180.85 \u003cbr\u003e order: 9"]]
//      }
//  ]
//      }
// ;
//              option && (option.backgroundColor = 'rgba(0,0,0,0)');
//              option && myChart.setOption(option);
//              elem.ondblclick = function () { myChart.resize() };
//              console.log('rendered new chart');
//          }
//          call_echarts(fn)
//      })()
//  </script>

// %%
TradeChart(trades, aspect = "cost")
// Out:
//  <div style="width:100%;height:500px;" class="rqcharts"></div>
//
//  <script type="text/javascript">
//      (function () {
//          let elem = document.currentScript.previousElementSibling;
//          let fn = function(a) {
//              var theme = document.body.dataset.jpThemeLight == 'false' ? 'dark' : 'light';
//              var myChart = echarts.init(elem, theme);
//              var option = {
//          xAxis: {
//              type: 'time',
//              scale: true
//          },
//          title: {
//              text: 'Trade Chart cost'
//          },
//          yAxis: {
//              type: 'value',
//              scale: true
//          },
//          visualMap: {
//             min: -17614.23,
//             max: 17614.23,
//             calculable: true,
//             orient: 'horizontal',
//             left: 'center',
//             dimension: 1,
//             top: 'top',
//             inRange : { color: ['#FF0000', '#00FF00'] }
//          },
//          tooltip: {
//               formatter: function (params) {
//                  return params.value[2];
//               }
//          },
//          dataZoom: [{ type: 'inside'}, {}],
//          toolbox: { feature: {
//              dataZoom: { yAxisIndex: 'none'},
//              dataView: {readOnly: true},
//              restore: {},
//              saveAsImage: {}
//          }},
//          grid: { left: '3%', right: '3%', containLabel: true },
//          series : [
//      {
//          type: 'scatter',
//          symbolSize: 10,
//          data : [[1453237200000,-17614.23,"asset: STOCK JPM \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2016-01-19T21:00:00Z\u003cbr\u003e\nqty: -358.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: -2433.40\u003cbr\u003e\ncost: -17614.23\u003cbr\u003e\norder: 2"],[1466712000000,-15326.75,"asset: STOCK TSLA \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2016-06-23T20:00:00Z\u003cbr\u003e\nqty: -392.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: -4528.28\u003cbr\u003e\ncost: -15326.75\u003cbr\u003e\norder: 6"],[1472846400000,-17180.85,"asset: STOCK TSLA \u003cbr\u003e\ncurrency: USD\u003cbr\u003e\ntime: 2016-09-02T20:00:00Z\u003cbr\u003e\nqty: -425.0\u003cbr\u003e\nfee: 0.00\u003cbr\u003e\npnl: -2856.67\u003cbr\u003e\ncost: -17180.85\u003cbr\u003e\norder: 9"]]
//      }
//  ]
//      }
// ;
//              option && (option.backgroundColor = 'rgba(0,0,0,0)');
//              option && myChart.setOption(option);
//              elem.ondblclick = function () { myChart.resize() };
//              console.log('rendered new chart');
//          }
//          call_echarts(fn)
//      })()
//  </script>

// %%
val asset = account.assets.first()
val timeframe = Timeframe.parse("2016-01-01", "2017-01-01")
PriceBarChart(feed, asset, account.trades, timeframe)
// Out:
//         <div style="width:100%;height:700px;" class="rqcharts"></div>
//
//         <script type="text/javascript">
//             (function () {
//                 let elem = document.currentScript.previousElementSibling;
//                 let fn = function(a) {
//                     var theme = document.body.dataset.jpThemeLight == 'false' ? 'dark' : 'light';
//                     var myChart = echarts.init(elem, theme);
//                     var option = {
// dataset: {
//     source: [[1451941200000,87.258,87.339,85.317,86.206,1.4825413E7,-1],[1452027600000,86.289,87.028,86.28,86.56,7538410.0,1],[1452114000000,85.634,86.618,85.446,86.126,9013725.0,1],[1452200400000,85.195,85.867,84.831,85.124,1.0994487E7,-1],[1452286800000,85.688,85.739,83.944,84.21,1.138317E7,-1],[1452546000000,84.282,84.613,82.427,83.707,9501595.0,-1],[1452632400000,84.064,84.613,83.423,84.282,7852271.0,1],[1452718800000,84.493,84.913,83.08,83.235,9656899.0,-1],[1452805200000,83.3,85.333,83.216,84.84,1.1838042E7,1],[1452891600000,82.678,84.071,82.572,83.216,1.4752975E7,1],[1453237200000,84.016,84.427,83.132,83.646,1.4521257E7,-1],[1453323600000,82.452,83.455,81.097,82.145,1.4772504E7,-1],[1453410000000,82.158,82.909,80.882,82.304,1.3130866E7,1],[1453496400000,83.235,83.288,82.314,83.0,9767952.0,-1],[1453755600000,82.976,83.806,82.396,82.701,1.0894067E7,-1],[1453842000000,83.436,86.943,83.331,86.803,2.0124824E7,1],[1453928400000,86.214,88.69,86.214,87.638,2.252449E7,1],[1454014800000,87.934,88.398,87.375,87.73,1.4907219E7,-1],[1454101200000,88.275,89.867,88.047,89.606,1.8189597E7,1],[1454360400000,88.879,89.892,88.557,89.551,1.1427269E7,1],[1454446800000,88.63,89.449,88.372,88.719,1.2369937E7,1],[1454533200000,88.915,89.56,87.516,89.342,1.1850203E7,1],[1454619600000,88.879,89.297,88.134,89.137,1.2109786E7,1],[1454706000000,88.076,88.171,85.601,86.257,1.8090958E7,-1],[1454965200000,86.059,88.798,85.978,87.508,1.6696161E7,1],[1455051600000,86.917,87.704,86.627,87.478,1.1706528E7,1],[1455138000000,87.548,88.294,86.968,87.273,1.1461609E7,-1],[1455224400000,86.189,87.525,85.773,87.252,1.453021E7,1],[1455310800000,87.348,87.488,86.413,87.348,1.0531291E7,1],[1455656400000,87.818,88.406,87.209,87.775,1.2173131E7,-1],[1455742800000,88.154,88.577,87.695,87.934,1.0374037E7,-1],[1455829200000,88.226,89.792,87.934,89.434,1.2513105E7,1],[1455915600000,89.515,90.461,89.334,89.992,1.0812033E7,1],[1456174800000,90.246,90.525,89.911,90.525,8035584.0,1],[1456261200000,90.434,90.562,89.83,89.938,7670177.0,-1],[1456347600000,89.297,90.803,88.975,90.705,1.0497021E7,1],[1456434000000,90.696,91.939,90.543,91.929,9364311.0,1],[1456520400000,92.309,92.382,91.095,91.395,1.0472442E7,-1],[1456779600000,90.978,91.773,90.776,90.912,1.1973891E7,-1],[1456866000000,91.503,92.654,91.115,92.637,9603164.0,1],[1456952400000,92.372,92.804,91.975,92.493,1.1302708E7,1],[1457038800000,92.309,92.458,91.269,92.171,8016444.0,-1],[1457125200000,92.042,92.439,91.659,92.042,7771584.0,1],[1457384400000,91.598,92.382,91.16,92.234,8070008.0,1],[1457470800000,92.051,92.263,91.559,91.789,8833144.0,-1],[1457557200000,92.328,92.476,91.678,92.328,8751615.0,1],[1457643600000,92.448,92.869,91.659,92.581,1.2121892E7,1],[1457730000000,92.888,93.315,92.628,93.082,8984145.0,1],[1457985600000,93.261,93.588,92.71,93.037,8381674.0,-1],[1458072000000,92.998,93.634,92.253,93.13,9809534.0,1],[1458158400000,93.101,93.148,92.354,92.804,8175595.0,-1],[1458244800000,92.859,92.98,91.995,92.234,9918793.0,-1],[1458331200000,92.448,93.193,91.921,92.888,1.7095926E7,1],[1458590400000,92.804,93.121,92.077,92.692,8881140.0,-1],[1458676800000,92.692,93.008,92.505,92.776,9051628.0,1],[1458763200000,92.701,94.03,92.628,93.766,9479388.0,1],[1458849600000,93.523,93.841,93.121,93.598,7272392.0,1],[1459195200000,93.682,94.096,93.383,93.533,5483115.0,-1],[1459281600000,93.588,94.407,93.111,94.313,7646392.0,1],[1459368000000,94.582,94.659,94.124,94.162,6073092.0,-1],[1459454400000,94.058,94.162,93.363,93.503,9451473.0,-1],[1459540800000,93.324,94.444,93.063,94.35,1.046504E7,1],[1459800000000,94.03,94.275,93.559,93.831,1.2341041E7,-1],[1459886400000,93.533,94.925,93.333,94.144,9186136.0,1],[1459972800000,93.935,94.611,93.233,94.555,7902498.0,1],[1460059200000,94.181,94.715,93.861,94.426,9049087.0,1],[1460145600000,94.506,94.734,93.974,94.275,7292440.0,-1],[1460404800000,94.322,94.715,93.88,94.162,7896798.0,-1],[1460491200000,94.181,95.258,93.965,94.697,9729436.0,1],[1460577600000,95.057,95.353,94.459,94.954,6663769 ...

// %%
val orders = account.closedOrders.filter { it.asset.symbol.startsWith("A") }
OrderChart(orders)
// Out:
//         <div style="width:100%;height:500px;" class="rqcharts"></div>
//
//         <script type="text/javascript">
//             (function () {
//                 let elem = document.currentScript.previousElementSibling;
//                 let fn = function(a) {
//                     var theme = document.body.dataset.jpThemeLight == 'false' ? 'dark' : 'light';
//                     var myChart = echarts.init(elem, theme);
//                     var option = {
//              xAxis: {
//                  type: 'time',
//                  scale: true
//              },
//              title: {
//                  text: 'Order Chart quantity'
//              },
//              yAxis: {
//                  type: 'value',
//                  scale: true
//              },
//              visualMap: {
//     min: -784.0,
//     max: 784.0,
//     calculable: true,
//     orient: 'horizontal',
//     left: 'center',
//     dimension: 1,
//     top: 'top',
//     inRange : { color: ['#FF0000', '#00FF00'] }
// },
//              tooltip: {
//                   formatter: function (params) {
//                      return params.value[2];
//                   }
//              },
//              dataZoom: [{ type: 'inside'}, {}],
//              toolbox: { feature: {
//                  dataZoom: { yAxisIndex: 'none'},
//                  dataView: {readOnly: true},
//                  restore: {},
//                  saveAsImage: {}
//              }},
//              grid: { left: '3%', right: '3%', containLabel: true },
//              series : [
//          {
//              type: 'scatter',
//              symbolSize: 10,
//              data : [[1472068800000,784.0,"asset: STOCK AAPL  \u003cbr\u003e currency: USD \u003cbr\u003e placed: 2016-08-24T20:00:00Z \u003cbr\u003e qty: 784.0 \u003cbr\u003e id: 8 \u003cbr\u003e type: MarketOrder \u003cbr\u003e tif: GTC"]]
//          }
//      ]
//          };
//                     option && (option.backgroundColor = 'rgba(0,0,0,0)');
//                     option && myChart.setOption(option);
//                     elem.ondblclick = function () { myChart.resize() };
//                     console.log('rendered new chart');
//                 }
//                 call_echarts(fn)
//             })()
//         </script>
